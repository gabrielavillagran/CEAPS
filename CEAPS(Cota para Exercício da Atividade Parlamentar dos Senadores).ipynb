# %% [markdown]
# <hr style='border: 1px solid black;'>
#
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: center; color:purple;'> <b>Analise dos dados da Cota para Exercício da Atividade Parlamentar dos Senadores (CEAPS) </b></p>
#
# <hr style='border: 1px solid black;'>
#
#
# <p style='font-size: 14px; line-height: 2; margin: 10px 50px; text-align: left; color:purple;'><i> Projeto desenvolvido por Gabriela Villagran</i></p>

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'> <b>1. Importando pandas, numpy e plotly</b></p>
#
# <a href = "https://pandas.pydata.org/docs/" style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Documentação Pandas </a>
#
# <a href = "https://numpy.org/doc/stable/user/index.html" style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Documentação Numpy </a>
#
# <a href = "https://plotly.com/python-api-reference/generated/plotly.graph_objects.Figure.html" style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Documentação Plotly </a>

# %%
import pandas as pd
import numpy as np

# !pip install plotly

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'> <b>1.1 Sobre os dados:</b></p>
#
# <a href = "https://www.kaggle.com/datasets/arjunbhasin2013/ccdata" style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Arquivo no Kaggle</a>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> O conjunto de dados resume as despesas das ativadades parlamentares dos senadores durante o ano de 2022. Abaixo estão explicitadas as features.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> <b>O que é a cota parlamentar ?</b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>A Cota para o Exercício da Atividade Parlamentar (CEAP), instituída pelo Ato da Mesa 43/2009, unificou a verba indenizatória (que vigorava desde 2001), a cota de passagens aéreas e a cota postal-telefônica. O valor mensal do benefício deve ser utilizado pelo deputado para custear despesas típicas do exercício do mandato parlamentar, como aluguel de escritório de apoio ao mandato no estado, passagens aéreas, alimentação, aluguel de carro, combustível, entre outras.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>O saldo mensal não utilizado em um mês acumula-se ao longo do exercício financeiro, vedada a acumulação de um exercício financeiro para o seguinte.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>A utilização da Cota Parlamentar pode ser feita por meio de reembolso ou por débito no valor da Cota. No último caso, é o que acontece com a requisição de serviço postal, na agência dos Correios credenciada pela Câmara dos Deputados, e com a reserva de passagens nas companhias aéreas credenciadas. No caso de débito, não há emissão individual de nota fiscal, uma vez que o contrato é assinado pela Câmara e não pelo parlamentar<p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>apresentar a documentação comprobatória do gasto. Os valores das notas fiscais apresentadas dentro desse prazo são debitados da cota do mês a que a despesa se refere. Desta maneira, antes de transcorridos os 90 dias, não é correto afirmar o total gasto por um parlamentar, uma vez que ele ainda pode apresentar documentos referentes a despesas de meses anteriores. O valor do reembolso referente ao uso da Cota é depositado na conta do deputado, em média, até três dias úteis depois da solicitação.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>O parlamentar assume inteira responsabilidade pela nota fiscal que apresenta (art. 4º do Ato da Mesa 43/2009). Cabe à Câmara, no âmbito administrativo, verificar os gastos apenas quanto à regularidade fiscal e contábil da documentação comprobatória (§10 do art. 4º do Ato da Mesa 43/2009).
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Despesas que podem ser pagas com a Cota Parlamentar
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>As despesas que podem ser pagas com os recursos da Cota Parlamentar são:</b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>1 - passagens aéreas;</li>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>2 – telefones dos gabinetes, dos escritórios nos estados e dos imóveis funcionais, e as despesas com o celular funcional do deputado. As contas devem ser de comprovada responsabilidade do parlamentar;</li>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>3 - serviços postais, exceto selos;</li>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>4 - manutenção de escritórios de apoio à atividade parlamentar, como locação de imóveis, energia elétrica, água e esgoto, acesso à internet, entre outros;</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>5 - alimentação do deputado;</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>6 – hospedagem, exceto no Distrito Federal;</li>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>7 - despesas com locomoção por:</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- locação ou fretamento de aeronaves;</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- locação ou fretamento de veículos automotores (limite inacumulável de R$ 12.713,00 mensais), permitida contratação de seguro;</li>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- locação ou fretamento de embarcações;</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- serviços de táxi, pedágio e estacionamento (limite inacumulável de R$ 2.700,00 mensais);</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- passagens terrestres, marítimas ou fluviais.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>8- combustíveis e lubrificantes (limite inacumulável de R$ 6.000,00 mensais);
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>9 - serviços de segurança de empresas especializadas (limite inacumulável de R$ 8.700,00 mensais);
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>10 - consultorias e trabalhos técnicos de apoio ao exercício parlamentar;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>11 - divulgação da atividade parlamentar (exceto nos 120 dias anteriores à data das eleições, se o deputado for candidato - Ato da Mesa 40/2012);
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>12 - participação em cursos, congressos ou eventos, realizados por instituição especializada (limite mensal inacumulável de 25% do valor da menor cota – hoje R$7.697,17);
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>13 - complementação de auxílio-moradia, de acordo com o Ato da Mesa 104/88 (limite inacumulável de R$1.747,00 mensais).
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Despesas que não podem ser pagas com a Cota Parlamentar
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Não são admitidos gastos com a utilização da cota para: </b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>1 - bens ou serviços adquiridos de empresa ou entidade da qual o deputado ou parente até o terceiro grau ou servidor da Câmara seja proprietário ou detentor de qualquer participação;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>2 - locação ou fretamento em empresas em que o deputado ou parente até o terceiro grau ou em que um servidor da Câmara sejam proprietários ou detentores de qualquer participação;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>3 - pagamento realizado à pessoa física, salvo para locação de imóvel, uso de aeronave ou embarcação, e serviços de táxi;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>4 - sem apresentação de nota fiscal, salvo se a empresa estiver legalmente isenta de emitir a nota;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>5 - aquisição de gêneros alimentícios;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>6 - aquisição de material permanente, de duração superior a dois anos;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>7 - locação de bens móveis com cláusulas que possibilitem sua aquisição com recursos da Cota;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>8 - locação de veículo automotor, prestada por pessoa jurídica especializada, que contemple o serviço de motorista;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>9 - gastos de caráter eleitoral;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>10 - gastos referentes à participação do deputado em cursos de educação básica, graduação e pós-graduação. </li>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Nos 120 dias anteriores à data das eleições gerais e municipais, os deputados que forem candidatos não poderão utilizar recursos da cota para pagar divulgação da atividade parlamentar (Ato da Mesa 40/2012).</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Adicional no valor da Cota Parlamentar </b></p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Alguns deputados recebem adicional de RS 1.353,04 no valor da Cota mensal  por exercer cargo de líder ou vice-líder de partido político ou de bloco parlamentar; líder do Governo na Câmara ou no Congresso; líder da Minoria; presidente ou vice-presidente de comissão permanente; e representante de partidos políticos com menos de um centésimo da composição da Casa. A Cota mensal é acrescida de RS 902,02 para os deputados que exercem cargos de vice-líder da Minoria ou do governo na Câmara ou no Congresso Nacional; e RS 5.075,62 no caso de suplente de secretário da Mesa Diretora.</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>O adicional não é cumulativo caso o parlamentar exerça mais de um desses cargos. </p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>O deputado que se deslocar em missão oficial pela Representação Brasileira no Parlamento do Mercosul fará jus a adicional de cota correspondente a 20% do valor da menor cota mensal por viagem realizada.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Despesas de assessores pagas com a Cota</b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Podem ser reembolsadas pela Cota as despesas de funcionários a serviço da atividade parlamentar do deputado com: passagens aéreas, terrestres, marítimas ou fluviais; hospedagem; locação ou fretamento de veículos, aeronaves e embarcações; serviços de táxi; pedágio; e estacionamento.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Disponibilização das notas fiscais </b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Desde julho de 2014, as cópias digitalizadas das notas fiscais referentes a gastos da Cota Parlamentar estão disponíveis no sistema de Cota Parlamentar, conforme Portaria 228/2014. A responsabilidade pela digitalização das notas fiscais é dos gabinetes parlamentares. O material digitalizado é encaminhado à área responsável pela administração da Cota, que se ocupa de tornar público o conteúdo dos documentos.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Algumas notas fiscais não são divulgadas na “Transparência” do portal da Câmara. São elas: </b>
#
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- despesas telefônicas, devido ao sigilo telefônico - O interessado pelo documento deve solicitá-lo por meio da Lei de Acesso à Informação (LAI) - disponível no portal, em Fale Conosco. O setor responsável fará o tarjamento dos trechos onde há informações sigilosas antes de enviar ao requerente. O mesmo procedimento vale para notas que identificam outros dados sigilosos, como o bancário; </p>
#
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- serviços postais utilizados por meio de Requisição de Serviço Postal (RSP) nas agências dos Correios credenciadas pela Câmara - o deputado emite uma RSP para utilizar os serviços da empresa; no fim de cada mês, os Correios emitem uma fatura global para a Câmara com os gastos com RSP, e as despesas do parlamentar são debitadas da sua Cota. Neste caso, não são emitidas notas fiscais individuais em nome do deputado, portanto, os gastos com serviços postais disponíveis na página da Cota vêm identificados com as iniciais “RSP” na coluna "Número do documento". No caso de utilização de serviços postais em agência dos Correios não credenciada, o deputado poderá pedir reembolso do gasto; </p>
#
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- gastos com passagens em companhias aéreas credenciadas pela Câmara são feitos mediante emissão de Requisição de Passagem Aérea (RPA). (Veja item abaixo)</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Passagem aérea</b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>A compra de passagem aérea para o exercício da atividade parlamentar por meio da Cota pode ser feita de três formas:
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Por Requisição de Passagem Aérea (RPA), cujas passagens são emitidas pelas companhias aéreas credenciadas pela Câmara. O processo funciona de forma similar aos gastos com serviços postais por Requisição de Serviço Postal (RSP), sendo as despesas com as passagens debitadas do valor da cota mensal do parlamentar, a partir de uma fatura global enviada à Câmara pelas empresas credenciadas. Como não são emitidas notas fiscais individuais, na página da Cota esse tipo de gasto aparece como “Passagem aérea - RPA", e na coluna "Número do documento", aparece o número do bilhete aéreo. A RPA tem validade para uso até o último dia útil do respectivo exercício financeiro.</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Por reembolso, quando o deputado compra passagem aérea para o exercício do mandato diretamente nas companhias aéreas. Neste caso, as despesas aparecem como “Passagem aérea”, e a nota fiscal é anexada em “Número do documento”.</p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Pelo Sistema de Gestão de Passagens Aéreas (Sigepa), que permite aos deputados e assessores credenciados a realização de reservas ou emissões, cancelamentos, remarcações, pedidos de reembolso de passagens aéreas, conforme regras e políticas de viagem estabelecidas entre a Câmara e as companhias aéreas credenciadas. O valor das passagens aéreas retiradas pelo Sigepa é debitado diretamente da cota mensal do parlamentar. Na página da Cota esse tipo de gasto aparece como “Passagem aérea - Sigepa", a data da compra, e na coluna "Número do documento", o número do bilhete aéreo. </p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Nos meses em que os gastos com passagem aérea pela Cota são destaques no gráfico disponível na Transparência do portal da Câmara, a nomenclatura "Passagem Aérea" constante da legenda, no campo "Em que tipo de despesa a Cota foi gasta?", traz a soma dos gastos com bilhetes aéreos emitidos por RPA e na modalidade reembolso. A modalidade "Sigepa" aparece separadamente.

# %%
# O formato do arquivo foi alterado para winlatin1 para não perder a formatação dos textos
dados = pd.read_excel('./dados/despesa_ceaps_2022.xlsx')

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'> <b> 2. Visualizando os dados</b>

# %%
dados.tail(10)
# Out:
#        ANO  MES           SENADOR  \
# 8880  2022    6  ZEQUINHA MARINHO
# 8881  2022    6  ZEQUINHA MARINHO
# 8882  2022    6  ZEQUINHA MARINHO
# 8883  2022    6  ZEQUINHA MARINHO
# 8884  2022    6  ZEQUINHA MARINHO
# 8885  2022    6  ZEQUINHA MARINHO
# 8886  2022    6  ZEQUINHA MARINHO
# 8887  2022    6  ZEQUINHA MARINHO
# 8888  2022    7  ZEQUINHA MARINHO
# 8889  2022    7  ZEQUINHA MARINHO
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 8880  Locomoção, hospedagem, alimentação, combustíve...  84.110.394/0024-17
# 8881  Locomoção, hospedagem, alimentação, combustíve...  84.110.394/0024-17
# 8882  Locomoção, hospedagem, alimentação, combustíve...  84.110.394/0024-17
# 8883  Locomoção, hospedagem, alimentação, combustíve...  84.110.394/0024-17
# 8884  Locomoção, hospedagem, alimentação, combustíve...  07.089.731/0001-02
# 8885  Locomoção, hospedagem, alimentação, combustíve...  13.676.643/0001-00
# ...

# %%
dados.shape
# Out:
# (8890, 11)

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> A última atualização dos dados é do dia <b> 19/07/2022 02:01</b>

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 20px 50px; text-align: justify; color:purple;'> <b> 3. Pré-processamento dos dados</b>

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'> <b> 3.1 Tratamento de dados faltantes</b>

# %%
dados.isna().sum()
# Out:
# ANO                     0
# MES                     0
# SENADOR                 0
# TIPO_DESPESA            0
# CNPJ_CPF                0
# FORNECEDOR              0
# DOCUMENTO             480
# DATA                    0
# DETALHAMENTO         4160
# VALOR_REEMBOLSADO       0
# COD_DOCUMENTO           0
# dtype: int64

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'> <b> 3.1 Type dos dados</b>

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8890 entries, 0 to 8889
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                8890 non-null   int64
#  1   MES                8890 non-null   int64
#  2   SENADOR            8890 non-null   object
#  3   TIPO_DESPESA       8890 non-null   object
#  4   CNPJ_CPF           8890 non-null   object
#  5   FORNECEDOR         8890 non-null   object
#  6   DOCUMENTO          8410 non-null   object
#  7   DATA               8890 non-null   object
#  8   DETALHAMENTO       4730 non-null   object
#  9   VALOR_REEMBOLSADO  8890 non-null   float64
#  10  COD_DOCUMENTO      8890 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 764.1+ KB

# %%
dados['VALOR_REEMBOLSADO'].unique()
# Out:
# array([6000.  , 1500.  , 1000.  , ..., 1364.86, 2944.06, 2532.14])

# %%
# Transformando valor reenbolsado em número
dados['VALOR_REEMBOLSADO'] = dados['VALOR_REEMBOLSADO'].astype('float64')

# Transformando variável DETALHAMENTO em texto para depois fazer o NLP
dados['DETALHAMENTO'] = dados['DETALHAMENTO'].astype('U')

# Trocando '),' por ' '
dados['DETALHAMENTO'] = dados['DETALHAMENTO'].str.replace(",", " ")
dados['DETALHAMENTO'] = dados['DETALHAMENTO'].str.replace(":", " ")
dados['DETALHAMENTO'] = dados['DETALHAMENTO'].str.replace("-", " ")

# Transformando variável DETALHAMENTO em texto para depois fazer o NLP
dados['TIPO_DESPESA'] = dados['TIPO_DESPESA'].astype('U')

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Por enquanto não serão aplicados nenhum tratamento dos dados faltantes.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'> <b> 3.1 Acrescentando estados no qual foram eleitos</b>

# %%
dicionario =  { "ACIR GURGACZ"           : "RO",
                "ALESSANDRO VIEIRA"      : "SE",
                "ALEXANDRE SILVEIRA"     : "MG",
                "ALVARO DIAS"            : "PR",
                "ANGELO CORONEL"         : "BA",
                "CARLOS PORTINHO"        : "RJ",
                "CARLOS VIANA"           : "MG",
                "CHICO RODRIGUES"        : "RR",
                "CID GOMES"              : "CE",
                "CONFÚCIO MOURA"         : "RO",
                "DANIELLA RIBEIRO"       : "PB",
                "DÁRIO BERGER"           : "SC",
                "DAVI ALCOLUMBRE"        : "AP",
                "DRA. EUDÓCIA"           : "AL",
                "EDUARDO BRAGA"          : "AM",
                "EDUARDO GIRÃO"          : "CE",
                "EDUARDO VELLOSO"        : "AC",
                "ELIANE NOGUEIRA"        : "PI",
                "ELIZIANE GAMA"          : "MA",
                "ELMANO FÉRRER"          : "PI",
                "ESPERIDIÃO AMIN"        : "SC",
                "FABIANO CONTARATO"      : "ES",
                "FABIO GARCIA"           : "MT",
                "FERNANDO BEZERRA COELHO": "PE",
                "FERNANDO COLLOR"        : "AL",
                "FLÁVIO ARNS"            : "PR",
                "FLÁVIO BOLSONARO"       : "RJ",
                "GIORDANO"               : "SP",
                "HUMBERTO COSTA"         : "PE",
                "IRAJÁ"                  : "TO",
                "IZALCI LUCAS"           : "DF",
                "JADER BARBALHO"         : "PA",
                "JAQUES WAGNER"          : "BA",
                "JARBAS VASCONCELOS"     : "PE",
                "JEAN PAUL PRATES"       : "RN",
                "JORGE KAJURU"           : "GO",
                "JORGINHO MELLO"         : "SC",
                "JOSÉ SERRA"             : "SP",
                "KÁTIA ABREU"            : "TO",
                "LASIER MARTINS"         : "RS",
                "LEILA BARROS"           : "DF",
                "LUCAS BARRETO"          : "AP",
                "LUIS CARLOS HEINZE"     : "RS",
                "LUIZ CARLOS DO CARMO"   : "GO",
                "LUIZ PASTORE"           : "ES",
                "MAILZA GOMES"           : "AC",
                "MARA GABRILLI"          : "SP",
                "MARCELO CASTRO"         : "PI",
                "MARCOS DO VAL"          : "ES",
                "MARCOS ROGÉRIO"         : "RO",
                "MARGARETH BUZETTI"      : "MT",
                "MARIA DAS VITÓRIAS"     : "AC",
                "MARIA DO CARMO ALVES"   : "SE",
                "MECIAS DE JESUS"        : "RR",
                "NELSINHO TRAD"          : "MS",
                "NILDA GONDIM"           : "PB",
                "OGARI PACHECO"          : "TO",
                "OMAR AZIZ"              : "AM",
                "ORIOVISTO GUIMARÃES"    : "PR",
                "PAULO PAIM"             : "RS",
                "PAULO ROCHA"            : "PA",
                "PLÍNIO VALÉRIO"         : "AM",
                "RAFAEL TENÓRIO"         : "AL",
                "RANDOLFE RODRIGUES"     : "AP",
                "REGUFFE"                : "DF",
                "ROBERTH BRINGEL"        : "MA",
                "ROBERTO ROCHA"          : "MA",
                "RODRIGO PACHECO"        : "MG",
                "ROGÉRIO CARVALHO"       : "SE",
                "ROMÁRIO"                : "RJ",
                "SIMONE TEBET"           : "MS",
                "SORAYA THRONICKE"       : "MS",
                "STYVENSON VALENTIM"     : "RN",
                "TASSO JEREISSATI"       : "CE",
                "TELMÁRIO MOTA"          : "RR",
                "VANDERLAN CARDOSO"      : "GO",
                "VENEZIANO VITAL DO RÊGO": "PB",
                "WELLINGTON FAGUNDES"    : "MT",
                "ZENAIDE MAIA"           : "RN",
                "ZEQUINHA MARINHO"       : "PA" }

dados['UF'] = dados['SENADOR'].map(dicionario)

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 20px 50px; text-align: justify; color:purple;'> <b> 4. Análises descritivas</b>

# %%
dados.describe().round(2)
# Out:
#           ANO      MES  VALOR_REEMBOLSADO  COD_DOCUMENTO
# count  8890.0  8890.00            8890.00        8890.00
# mean   2022.0     3.67            1540.47     2178622.19
# std       0.0     1.66            2902.89        3073.15
# min    2022.0     1.00               0.01     2172906.00
# 25%    2022.0     2.00             200.05     2176006.25
# 50%    2022.0     4.00             483.25     2178700.50
# 75%    2022.0     5.00            1962.72     2181228.75
# max    2022.0     7.00           77012.00     2184020.00

# %%
# Descobrindo qual a maior despesa de 77012.00

dados.query('VALOR_REEMBOLSADO == 77012.00')
# Out:
#        ANO  MES         SENADOR  \
# 7607  2022    2  SÉRGIO PETECÃO
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 7607  Contratação de consultorias, assessorias, pesq...  12.980.692/0001-60
#
#                  FORNECEDOR DOCUMENTO        DATA DETALHAMENTO  \
# 7607  P. H. A. RAMALHO - ME        66  28/02/2022          nan
#
#       VALOR_REEMBOLSADO  COD_DOCUMENTO   UF
# 7607            77012.0        2175346  NaN

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 20px 50px; text-align: justify; color:purple;'> <b> 4.1 Top 10 dos senadores com maiores declaração de despesas</b>

# %%
# Agrupando as despesas por senador
dados.groupby('SENADOR').sum()['VALOR_REEMBOLSADO'].to_frame()

# Criando dataframe das top despesas
top_despesas = pd.DataFrame(dados.groupby('SENADOR').sum()['VALOR_REEMBOLSADO'])
top_despesas = top_despesas.sort_values(by ='VALOR_REEMBOLSADO', ascending=False)[:10].reset_index()
top_despesas['UF'] = top_despesas['SENADOR'].map(dicionario)

# %%
top_despesas
# Out:
#               SENADOR  VALOR_REEMBOLSADO  UF
# 0           OMAR AZIZ          289226.29  AM
# 1     CHICO RODRIGUES          287762.15  RR
# 2    ROGÉRIO CARVALHO          279908.32  SE
# 3     MECIAS DE JESUS          266298.13  RR
# 4       LUCAS BARRETO          263189.44  AP
# 5        MAILZA GOMES          263014.16  AC
# 6       ELMANO FÉRRER          261744.49  PI
# 7       TELMÁRIO MOTA          254680.95  RR
# 8  RANDOLFE RODRIGUES          253399.00  AP
# 9       ELIZIANE GAMA          249577.14  MA

# %%
import plotly.offline as py
import plotly.graph_objs as go

py.init_notebook_mode(connected=True)

# Filtrando o senador
dados.groupby('SENADOR').sum().reset_index()['SENADOR']

# Filtando as despesas totais de cada senador
dados.groupby('SENADOR').sum().reset_index()['VALOR_REEMBOLSADO']

# Criando o scatterplot
trace = go.Bar(x = dados.groupby('SENADOR').sum().reset_index()['SENADOR'],
               y= dados.groupby('SENADOR').sum().reset_index()['VALOR_REEMBOLSADO'])


data = [trace]
fig = go.Figure(data=data)

fig.update_traces(textfont_size=16, textangle=0, textposition="outside", cliponaxis=False)

py.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
import plotly.offline as py
import plotly.graph_objs as go

py.init_notebook_mode(connected=True)

# Filtrando o senador
filtro_senador = dados.groupby('SENADOR').sum().reset_index().sort_values(by ='VALOR_REEMBOLSADO', ascending=False)['SENADOR']

# Filtando as despesas totais de cada senador
filtro_top_despesa = dados.groupby('SENADOR').sum().reset_index().sort_values(by ='VALOR_REEMBOLSADO', ascending=False)['VALOR_REEMBOLSADO']

# Criando o scatterplot
trace = go.Bar(x = filtro_senador,
               y= filtro_top_despesa)

data = [trace]
fig = go.Figure(data=data)

fig.update_traces(textfont_size=16, textangle=45, textposition="outside", cliponaxis=False)

py.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
dados['TIPO_DESPESA'].unique()
# Out:
# array(['Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.',
#        'Divulgação da atividade parlamentar',
#        'Passagens aéreas, aquáticas e terrestres nacionais',
#        'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar',
#        'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes',
#        'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ',
#        'Serviços de Segurança Privada'], dtype=object)

# %%
# Obtendo as despesas de Omar Aziz
despesas_de_consultoria_omar = dados.query('SENADOR == "OMAR AZIZ" & TIPO_DESPESA == "Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"').sort_values(by= 'VALOR_REEMBOLSADO', ascending=False)
despesas_de_consultoria_omar.head()
# Out:
#        ANO  MES    SENADOR                                       TIPO_DESPESA  \
# 6323  2022    1  OMAR AZIZ  Contratação de consultorias, assessorias, pesq...
# 6325  2022    2  OMAR AZIZ  Contratação de consultorias, assessorias, pesq...
# 6328  2022    3  OMAR AZIZ  Contratação de consultorias, assessorias, pesq...
# 6331  2022    4  OMAR AZIZ  Contratação de consultorias, assessorias, pesq...
# 6335  2022    5  OMAR AZIZ  Contratação de consultorias, assessorias, pesq...
#
#                 CNPJ_CPF                                         FORNECEDOR  \
# 6323  15.183.160/0001-90  UPLINK Assessoria e Consultoria Empresarial Ei...
# 6325  15.183.160/0001-90  UPLINK Assessoria e Consultoria Empresarial Ei...
# 6328  15.183.160/0001-90  UPLINK Assessoria e Consultoria Empresarial Ei...
# 6331  15.183.160/0001-90  UPLINK Assessoria e Consultoria Empresarial Ei...
# 6335  15.183.160/0001-90  UPLINK Assessoria e Consultoria Empresarial Ei...
#
# ...

# %%
print('R$', despesas_de_consultoria_omar.sum()['VALOR_REEMBOLSADO'])
# Out:
# R$ 230000.0

# %%
# Filtrando o total gasto
total_gasto_omar = pd.DataFrame(dados.groupby('SENADOR').sum()['VALOR_REEMBOLSADO']).reset_index()
total_gasto_omar = total_gasto_omar.query('SENADOR == "OMAR AZIZ"')
total_gasto_omar['VALOR_REEMBOLSADO']
# Out:
# 60    289226.29
# Name: VALOR_REEMBOLSADO, dtype: float64

# %%
porcentagem_omar = despesas_de_consultoria_omar['VALOR_REEMBOLSADO'].sum()/ total_gasto_omar['VALOR_REEMBOLSADO'] * 100
print(porcentagem_omar)
# Out:
# 60    79.522508
# Name: VALOR_REEMBOLSADO, dtype: float64

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> O senador Omar Aziz, gastou um total de R$ 230.000,00 reais em despesas do tipo "Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar", valor expressivo de <b>79,52%</b> do total gasto. O serviço foi fornecido pela impresa <b>Uplink Assessoria e Consultoria Empresarial Eireli</b>. Após pesquisas, no site da empresa é descrito seus serviços como :
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> <b>Atividade Principal:</b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Atividades de consultoria em gestão empresarial, exceto consultoria técnica específica
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Atividades Secundárias</b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Impressão de livros, revistas e outras publicações periódicas
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Comércio atacadista de livros, jornais e outras publicações
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Edição integrada à impressão de jornais diários
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Portais, provedores de conteúdo e outros serviços de informação na internet
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Agências de publicidade
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Pesquisas de mercado e de opinião pública
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>- Serviços de organização de feiras, congressos, exposições e festas

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 20px 50px; text-align: justify; color:purple;'> <b> 4.2 Top 10 dos tipos de despesas declaradas</b>

# %%
# Agrupando tipos de despesa
dados.groupby('TIPO_DESPESA').sum()['VALOR_REEMBOLSADO'].to_frame()

# Criando dataframe das top despesas
top_tipos_de_despesa = pd.DataFrame(dados.groupby('TIPO_DESPESA').sum()['VALOR_REEMBOLSADO'])
top_tipos_de_despesa.sort_values(by ='VALOR_REEMBOLSADO', ascending=False)[:10].reset_index()
# Out:
#                                         TIPO_DESPESA  VALOR_REEMBOLSADO
# 0  Passagens aéreas, aquáticas e terrestres nacio...         3793450.15
# 1  Contratação de consultorias, assessorias, pesq...         2809391.77
# 2  Locomoção, hospedagem, alimentação, combustíve...         2724387.92
# 3  Aluguel de imóveis para escritório político, c...         2025401.38
# 4                Divulgação da atividade parlamentar         1820046.39
# 5  Aquisição de material de consumo para uso no e...          517113.13
# 6                      Serviços de Segurança Privada            4955.94

# %%
import plotly.offline as py
import plotly.graph_objs as go

py.init_notebook_mode(connected=True)

# Filtrando os tipos de despesas
dados.groupby('TIPO_DESPESA').sum().reset_index()['TIPO_DESPESA']

# Filtando os totais de cada despesa
dados.groupby('TIPO_DESPESA').sum().reset_index()['VALOR_REEMBOLSADO']

# Criando o scatterplot
trace = go.Bar(x = dados.groupby('TIPO_DESPESA').sum().reset_index()['TIPO_DESPESA'],
               y= dados.groupby('TIPO_DESPESA').sum().reset_index()['VALOR_REEMBOLSADO'])

data = [trace]
fig = go.Figure(data=data)
py.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
dados.describe()
# Out:
#           ANO          MES  VALOR_REEMBOLSADO  COD_DOCUMENTO
# count  8890.0  8890.000000        8890.000000   8.890000e+03
# mean   2022.0     3.666929        1540.466443   2.178622e+06
# std       0.0     1.657703        2902.888563   3.073153e+03
# min    2022.0     1.000000           0.010000   2.172906e+06
# 25%    2022.0     2.000000         200.050000   2.176006e+06
# 50%    2022.0     4.000000         483.250000   2.178700e+06
# 75%    2022.0     5.000000        1962.722500   2.181229e+06
# max    2022.0     7.000000       77012.000000   2.184020e+06

# %%
# Obtendo as maiores despesas
dados.sort_values(by= 'VALOR_REEMBOLSADO', ascending=False)[:10]
# Out:
#        ANO  MES          SENADOR  \
# 7607  2022    2   SÉRGIO PETECÃO
# 6156  2022    7  MECIAS DE JESUS
# 6343  2022    7        OMAR AZIZ
# 6203  2022    5    NELSINHO TRAD
# 6193  2022    4    NELSINHO TRAD
# 6181  2022    3    NELSINHO TRAD
# 6323  2022    1        OMAR AZIZ
# 6337  2022    6        OMAR AZIZ
# 6335  2022    5        OMAR AZIZ
# 6325  2022    2        OMAR AZIZ
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 7607  Contratação de consultorias, assessorias, pesq...  12.980.692/0001-60
# 6156                Divulgação da atividade parlamentar  84.017.888/0001-65
# 6343  Contratação de consultorias, assessorias, pesq...  15.183.160/0001-90
# 6203                Divulgação da atividade parlamentar  23.187.261/0001-68
# 6193                Divulgação da atividade parlamentar  23.187.261/0001-68
# 6181  Contratação de consultorias, assessorias, pesq...  37.195.146/0001-40
# ...

# %%
# O total de despesas
dados['VALOR_REEMBOLSADO'].sum()
# Out:
# 13694746.68

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Como essas informações datam de <b>19/07/2022</b>, até o momento os senadores foram reembolsados em um total de R$ 13.694.746,68 (13 milhões 694 mil 746 reais e 68 centavos).

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 20px 50px; text-align: justify; color:purple;'> <b> 4.3 Meses de maior despesa</b>

# %%
# Filtrando os meses com maior despesas
maior_despesa_por_mes = dados.groupby('MES').sum()['VALOR_REEMBOLSADO'].reset_index()
maior_despesa_por_mes = pd.DataFrame(maior_despesa_por_mes)

# Alternado número por meses
dicionario = {1: 'Janeiro',
              2: 'Fevereiro',
              3: 'Março',
              4: 'Abril',
              5: 'Maio',
              6: 'Junho',
              7: 'Julho'}

# Trocando o nome dos meses
maior_despesa_por_mes['MES'] = maior_despesa_por_mes['MES'].map(dicionario)

# Colocando em ordem de maior para menor
maior_despesa_por_mes.sort_values(by = 'VALOR_REEMBOLSADO', ascending=False)
# Out:
#          MES  VALOR_REEMBOLSADO
# 2      Março         2668067.71
# 4       Maio         2408402.28
# 3      Abril         2321511.91
# 1  Fevereiro         2213885.22
# 5      Junho         1803223.83
# 0    Janeiro         1790123.59
# 6      Julho          489532.14

# %%
# Filtando os totais de cada despesa
detalhamento = dados.groupby('DETALHAMENTO').sum().reset_index().sort_values(by = 'VALOR_REEMBOLSADO', ascending=False)[['DETALHAMENTO', 'VALOR_REEMBOLSADO']]

# %%
detalhamento
# Out:
#                                            DETALHAMENTO  VALOR_REEMBOLSADO
# 2923                                                nan         5758225.64
# 1936  Consultorias  assessorias  pesquisas  trabalho...          125000.00
# 2158   Despesa com divulgação da atividade parlamentar.          102677.42
# 2610  Prestação de serviços técnicos especializados ...           90000.00
# 2858  Valor pago referente ao serviço de divulgação ...           85568.74
# ...                                                 ...                ...
# 2382  Despesa de pedágio referente ao deslocamento d...               8.30
# 2320  Despesa com serviço de suporte técnico em info...               5.42
# 272   Companhia Aérea  AZUL  Localizador  NN2E6U. Pa...               3.00
# 253   Companhia Aérea  AZUL  Localizador  MGMLGZ. Pa...               0.01
# 1637  Companhia Aérea  LATAM  Localizador  TGJGQI. P...               0.01
#
# [2937 rows x 2 columns]

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>5. Explorando dados textuais </b>

# %%
# Vendo um dos detalhamentos
dados['DETALHAMENTO'][1]
# Out:
# 'Despesa com divulgação da atividade parlamentar no website www.informanahora.com'

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>5. Explorando dados textuais </b>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>O algoritmo de bag-of-words é muito conhecido e já foi amplamente discutido e implementado por outros desenvolvedores. O modelo bag-of-words é uma representação simplificadora usada no processamento de linguagem natural. Nesse modelo, um texto (como uma frase ou um documento) é representado como a bolsa de suas palavras, desconsiderando a gramática e até mesmo a ordem das palavras, mas mantendo a multiplicidade.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Pegará a frase e criacrá um vetor de representação
vetorizar = CountVectorizer(lowercase=False)

## Aplicando o CountVectorizer no nosso corpus textual
# Esta transformação, usaremos um método embutido do CountVectorizer chamado fit_transform, que receberá o array e criará a representação Bag of words. 
bag_of_words = vetorizar.fit_transform(dados['DETALHAMENTO'])
bag_of_words
# Out:
# <8890x4428 sparse matrix of type '<class 'numpy.int64'>'
# 	with 69740 stored elements in Compressed Sparse Row format>

# %%
# Tamanho do vetor criado
bag_of_words.shape
# Out:
# (8890, 4428)

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 2px 50px; text-align: justify;'> Ele foi representado por um vetor com 8890 dimensões, vetor grande, que custa armazenamento de memória, gasta processamento. Para melhorar isso é possível atribuir o parâmetro <i><b>max_features</b></i>, que limita o tamanho do vetor, porém as palavras que estarão contidas no vetor serão palavras que mais aparecem no corpus textual.

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 2px 50px; text-align: justify;'>  Importante lembrar que estamos vetorizando os dados de <i><b>teste e de treino</b></i>, desta maneira não corremos o risco de que os dados de teste contenham palavras que não estejam contidas no vocabulário (dados de treino).
#     Em produção, por exemplo, teríamos que pegar o modelo e criar a representação Bag of words a cada entrada nova, porque nosso foco serão métodos que irão ajudar a trazer as palavras mais relevantes possíveis para mais perto das <i><b>50 primeiras posições</b></i>, o que melhorará nossos resultados de forma expressiva.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>  6. Criando os *Datasets* de Treino e Teste com os dados preparados</b></p>
#
# <a style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;' href = "https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html"> Documentação </a>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'><b>Dados de Treino:</b>
# Conforme podemos imaginar, dados de treino são os dados que serão apresentados ao algoritmo de machine learning para criação do modelo. Estes dados costumam representar cerca de 70% da totalidade dos dados.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'><b>Dados de Teste:</b>
# Serão apresentados ao modelo após a sua criação, simulando previsões reais que o modelo realizará, permitindo assim que o desempenho real seja verificado. Estes dados costumam representar cerca de 30% da totalidade dos dados.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Referência : https://didatica.tech/dados-de-treino-e-teste/</p>

# %%
from sklearn.model_selection import train_test_split

# Separando a variavel dependente e as independentes
X = bag_of_words
y = dados['TIPO_DESPESA']

# Criando a semente
SEED = 12

# Separando em treino e teste

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=SEED)

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>6.1 Criando modelo de Regressão *LogisticRegression* </b>
#
# <a style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;' href = "https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html"> Documentação </a>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>A regressão logística é usada no aprendizado de máquina (ML) para ajudar a criar previsões precisas. É semelhante à regressão linear, exceto que, em vez de um resultado gráfico, a variável de destino é binária; o valor é 1 ou 0.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'>Existem três tipos básicos de regressão logística:
#
# <li style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Regressão logística binária:</b> aqui, há apenas dois resultados possíveis para a resposta categórica. Como no exemplo acima - um aluno é aprovado ou reprovado.</li>
#
# <li style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Regressão logística multinomial:</b> é onde as variáveis de resposta podem incluir três ou mais variáveis, que não estarão em nenhuma ordem. Um exemplo é prever se os clientes de um restaurante preferem um certo tipo de comida - vegetariana, carne ou vegana.</li>
# <li style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'><b>Regressão logística ordinal:</b> Como a regressão multinomial, pode haver três ou mais variáveis. No entanto, há uma ordem que as medições seguem. Um exemplo é classificar um hotel em uma escala de 1 a 5.</li>

# %%
from sklearn.linear_model import LogisticRegression

# Criando o modelo
regressao_logistica = LogisticRegression(solver='liblinear', max_iter=100)

# Treinando o modelo
regressao_logistica.fit(X_train, y_train)

# Testando o modelo
acuracia = regressao_logistica.score(X_test, y_test) * 100

# Mostrando na tela
print('Acurracy: ', acuracia.round(3), '%')
# Out:
# Acurracy:  74.179 %

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'><i><b>solver{'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'}, default='lbfgs'<b></i>
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Algoritmo para usar no problema de otimização. Padrão é 'lbfgs'. Para escolher um solucionador, você pode querer considerar os seguintes aspectos:
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Para pequenos conjuntos de dados, 'liblinear' é uma boa escolha, enquanto 'sag' e 'saga' são mais rápidos para os grandes;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Para problemas multiclasse, apenas 'newton-cg', 'sag', 'saga' e 'lbfgs' lidam com perda multinomial;
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>'liblinear' está limitado a esquemas de um contra descanso.
#
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'> O modelo está conseguindo prever de maneira correta aproximadamente 74% dos dados, é um resultado expressivo, pois a máquina está acertando mais do que a média.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>6.2 Criando uma função para classificar os tipos de despesas</b>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


def classificar_texto(texto, coluna_texto, coluna_classificacao):
    # Pegará nossa frase e criará um vetor de representação.
    vetorizar = CountVectorizer(lowercase=False)

    # Aplicando o CountVectorizer no nosso corpus textual 
    bag_of_words = vetorizar.fit_transform(texto[coluna_texto])
    
    # Criando uma semente
    SEED = 12

    # Separando em treino e teste
    X_train, X_test, y_train, y_test = train_test_split(bag_of_words,
                                                        texto[coluna_classificacao],
                                                        test_size=0.25,
                                                        random_state=SEED)
    # Criando o modelo
    regressao_logistica = LogisticRegression(solver = 'liblinear', max_iter=100)

    # Treinando o modelo
    regressao_logistica.fit(X_train, y_train)

    # Testando o modelo
    return regressao_logistica.score(X_test, y_test) * 100
    

# Mostrando na tela
print('Acurracy: ', classificar_texto(dados, 'DETALHAMENTO', 'TIPO_DESPESA').round(2), '%')
# Out:
# Acurracy:  74.18 %

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'><b>Resumo:</b> Deve-se selecionar todos os comentários e vetorizá-los. Depois é necessário dividir os dados em treino e teste para então determinar um método de classificação que trabalhe bem com dados esparsos. Por fim, deve-se treinar o classificador escolhido, realizar a previsão e medir os dados de teste.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>7. WordCloud - conhecendo a visualização</b>
#
# <a href = 'https://github.com/amueller/word_cloud' style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Instruções de uso</a>
#
# <a href = 'http://amueller.github.io/word_cloud/' style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> API reference</a>
#
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Será gerada a chamada <i><b>Word cloud</b></i>, a partir de uma biblioteca simples, que facilita em muito a criação de uma Word cloud, que você já até deve ter visto em algum site ou lugar. O que ela nos destaca? As palavras com maior frequência, que aparecem maiores e ocupam maior espaço na figura. Isso nos passa uma ideia geral de quais palavras se destacam em nosso corpus textual.

# %%
# Instalando a biblioteca
# !pip install wordcloud

# %%
# Juntando todas as frases

todas_palavras = [texto for texto in dados['DETALHAMENTO']]
todas_palavras[:4]
# Out:
# ['Despesa com pagamento de aluguel de imóvel para uso do escritório político do Senador Acir Gurgacz em Ji Paraná/RO.',
#  'Despesa com divulgação da atividade parlamentar no website www.informanahora.com',
#  'Despesa com produção de texto e edição de vídeo para divulgação da atividade parlamentar',
#  'Divulgação da atividade parlamentar']

# %%
# Juntando todas as frases
todas_palavras = ' '.join([texto for texto in dados['DETALHAMENTO']])
len(todas_palavras)
# Out:
# 549113

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Agora temos o que precisamos para gerar a nossa Word cloud. Em seguida, temos que construí-la, e para isso criaremos <i><b>nuvem_palavras</b></i>, que será igual a WordCloud em que, para gerarmos a nuvem de palavras, utilizaremos o método <i><b>generate()</b></i>, passando a variável contendo todas as palavras.

# %%
from wordcloud import WordCloud
# %matplotlib inline

# nuvem de palavras
nuvem_palavras = WordCloud(background_color='black').generate(todas_palavras)
nuvem_palavras

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>7.1 Transformando em imagem com o Matplotlib</b>
#
# <a href = 'https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html' style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Documentação </a>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>É um objeto, então, agora, precisaremos pegá-lo e <b>transformá-lo em uma imagem</b> utilizando o matplotlib, a ser importada, import matplotlib.pyplot as plt.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12))
plt.imshow(nuvem_palavras)

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>É possível então ver as palavras em destaque, sendo que a palavra filme aparece mais de uma vez, as palavras não estão nitidas. A seguir será apresentada a maneira de melhorar essa imagem.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>7.1.1 Melhorando a apresendaração da imagem</b>
#
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Primeiro mexeremos na parte do WordCloud; por padrão, uma das coisas que vem na biblioteca são a largura e a altura não da nossa imagem, mas <b>o tamanho que a Word cloud irá distribuir as palavras</b>. Por default, ela vem em 400 x 200, mas para a quantidade de palavras que temos e queremos neste corpus textual, um tamanho interessante seria 800 x 500, que venho utilizando em todas as Word clouds que faço mundo afora.
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Quando olhamos a imagem que geramos, algo que me desagrada um pouco é ter imagens muito grandes ocupando um espaço muito grande, claro, isso se relaciona à sua proporção e frequência dela em nosso texto, mas definir um tamanho máximo é melhor para termos um parâmetro um pouco melhor.

# %%
from wordcloud import WordCloud
# %matplotlib inline

# Juntando todas as frases totalmente juntas
todas_palavras = ' '.join([texto for texto in dados['DETALHAMENTO']])

# criando a núvem de palavras
nuvem_palavras = WordCloud(width=1024,height=768,
                           max_font_size=110,
                           collocations= False,
                           min_word_length = 3,
                           background_color='white').generate(todas_palavras)

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Na documentação do <b><a href='http://amueller.github.io/word_cloud/'>WordCloud</a></b>, temos a explicação do collocations, então se passamos como true, que é o default, o cálculo das frequências será feito pelo bigrama, e agora só queremos o cálculo da frequência das palavras, e não o bigrama. Já setamos o collocations = False, vamos também tirar as numerações dos eixos com plt.axis("off").m
#
# <li style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>bigrama: Sequência de duas <i><b>palavras</b><i> consecutivas ou dois números consecutivos.

# %%
# Mostrando a imagem
import matplotlib.pyplot as plt

# Alterando o tamanho da imagem
plt.figure(figsize=(12,12))

# Deixando a imagem mais nítida
plt.imshow(nuvem_palavras, interpolation='bilinear')

# Retirando numeração dos eixos
plt.axis('off')
# Out:
# (-0.5, 1023.5, 767.5, -0.5)

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>7.2.1 Função para nuvem de palavras positivas</b></p>

# %%
from wordcloud import WordCloud
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline

def criando_de_nuvem_palavras(texto,coluna_texto):
    # endereço local da imagem
    brasil_mask = np.array(Image.open("img/brasil1.jpg"))
    
    # Juntando todas as frases 
    todas_palavras = ' '.join([texto for texto in dados[coluna_texto]])

    # criando a núvem de palavras
    nuvem_palavras = WordCloud(width=1024,height=768,
                               max_font_size=110,
                               collocations= False,
                               background_color='white',
                               mask=brasil_mask).generate(todas_palavras)
    # Mostrando a imagem
    import matplotlib.pyplot as plt

    # Alterando o tamanho da imagem
    plt.figure(figsize=(12,12))

    # Deixando a imagem mais nítida
    plt.imshow(nuvem_palavras, interpolation='bilinear')
    
    # Retirando numeração dos eixos
    plt.axis('off')

# %%
criando_de_nuvem_palavras(dados,'DETALHAMENTO')

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>7.3 Frequência das palavras:</b> utilizando a biblioteca NLTK</p>
#
# <a href = 'https://www.nltk.org/' style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Documentação </a>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Vamos criar a visualização que nos ajudará a entender quais são 50, 10 ou 20 primeiras palavras com maior frequência. Para isso utilizaremos uma biblioteca Python, talvez uma das melhores que temos em Processamento de Linguagem Natural chamado NLTK (Natural Language Toolkit). É uma biblioteca muito rica e boa, que além de ter muitos dados apresenta suportes para algoritmos em português e inglês, pois diferentemente de algumas outras áreas da computação, no PLN as línguas mudam, e os algoritmos se comportam de acordo com elas.

# %%
import nltk

#nltk.download('all')

# %%
from nltk import tokenize

# Token com espaço em branco
token_espaco = tokenize.WhitespaceTokenizer()

#  Tokenizando a frase
token_frase = token_espaco.tokenize(todas_palavras)

# Obtendo a frequência das frases, mas queremos é a frequencia das palavras
frequencia = nltk.FreqDist(token_frase)

# Criando um dataframe da frequência
df_frequencia = pd.DataFrame({'Palavra':list(frequencia.keys()),
                              'Frequencia':list(frequencia.values())})

df_frequencia
# Out:
#         Palavra  Frequencia
# 0       Despesa        1092
# 1           com        1055
# 2     pagamento          77
# 3            de        2022
# 4       aluguel          76
# ...         ...         ...
# 5046    XEGFXY.           1
# 5047    BSB/MAB           1
# 5048    KPRGXR.           1
# 5049    EWEXLJ.           1
# 5050       3404           1
#
# [5051 rows x 2 columns]

# %%
# Ordenando as 10 palavras de maior frequência
df_frequencia_top_10 = df_frequencia.nlargest(columns='Frequencia', n=10)
df_frequencia_top_10
# Out:
#           Palavra  Frequencia
# 159           nan        4160
# 39     (Matrícula        2112
# 42            Voo        2112
# 3              de        2022
# 30      Companhia        1806
# 31          Aérea        1806
# 33    Localizador        1806
# 35    Passageiros        1806
# 41   PARLAMENTAR)        1494
# 0         Despesa        1092

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>As palavras com maior frequência envolvem "-", "<NA>", "de", ":", e outras, que não nos agregam tanto semanticamente. De cara, já vemos que podemos remover tais palavras de uso mais comum, mas antes disso vamos criar uma visualização.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>9. Stop Words - removendo o que não agrega</b></p>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>São palavras que não agregam pelo menos semanticamente, são irrelevantes, são chamadas em Processamento de Linguagem Natural, de Stop words, e existe uma lista padrão delas. Para podermos ter acesso a ela, importamos do nltk. Criaremos, então, palavras_irrelevantes, que será igual a nltk.corpus.stopwords.words.

# %%
# Retirando palavras irrelevantes do algoritmo
palavras_irrelevantes = nltk.corpus.stopwords.words('portuguese')
palavras_irrelevantes
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
# ...

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>Agora, deve-se fazer um tratamento no dataset, ou seja, pegar nosso DataFrame e, em cada frase, temos que retirar as Stop words. Faremos um <b>script de pré-processamento</b> um pouco longo, e não vai dar pra ficar quebrando ele para ficar mostrando os resultados imediatos, então vamos fazer passo a passo. Precisamos acessar cada linha do nosso DataFrame da coluna texto_portugues, precisamos ter acesso a estas opiniões.

# %%
frase_processada = list()

for despesa in dados['DETALHAMENTO']:
    
    # Se a palavra não for irrelevante ela entrará na lista
    nova_frase = list()
    
    # separando a frase palavra por palavra
    palavras_texto = token_espaco.tokenize(despesa)
    
    # Iterar em cada palavra do texto
    for palavra in palavras_texto:
        if palavra not in palavras_irrelevantes:
            # lista com todas as palavras da frase que não são irrelevantes
            nova_frase.append(palavra)
    
    # Juntando todas as frases
    frase_processada.append(' '.join(nova_frase))

# resenha['tratamento_1'] é a coluna texto_portugues sem as stop words, sem as palavras irrelevantes
dados['TRATAMENTO_1'] = frase_processada

# %%
dados['DETALHAMENTO'][0]
# Out:
# 'Despesa com pagamento de aluguel de imóvel para uso do escritório político do Senador Acir Gurgacz em Ji Paraná/RO.'

# %%
dados['TRATAMENTO_1'][0]
# Out:
# 'Despesa pagamento aluguel imóvel uso escritório político Senador Acir Gurgacz Ji Paraná/RO.'

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'> Como mostra acima, pegamos a primeira frase para comparar ela sem os stopwords

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>10.1 Separando pontuação das palavras</b></p>
#
# -- Exemplo
# perfeito, o filme.
# o filme é perfeito
#
# -- Ao fazer a tokenização da palavra "perfeito" das duas frases, elas teriam frequências diferentes por causa das pontuações.
#
# perfeito,
# perfeito.

# %%
from string import punctuation

# Pontuações para serem retiradas do texto
punctuation

# Fazendo a tokenização pela pontuação e espaço
token_espaco = tokenize.WhitespaceTokenizer()
token_pontuacao = tokenize.WordPunctTokenizer()

# Ela está em uma unica string, deve ser feita uma lista dela
pontuacao = list()

for ponto in punctuation:
    pontuacao.append(ponto)
    
# Adicionando as pontuações na lista de stop works
pontuacao_stopwords = pontuacao + palavras_irrelevantes

frase_processada = list()
for despesa in dados['TRATAMENTO_1']:
    nova_frase = list()
    palavras_texto = token_pontuacao.tokenize(despesa)
    for palavra in palavras_texto:
        if palavra not in pontuacao_stopwords:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))
    
dados['TRATAMENTO_2'] = frase_processada

# %%
dados['TRATAMENTO_1'][0]
# Out:
# 'Despesa pagamento aluguel imóvel uso escritório político Senador Acir Gurgacz Ji Paraná/RO.'

# %%
dados['TRATAMENTO_2'][0]
# Out:
# 'Despesa pagamento aluguel imóvel uso escritório político Senador Acir Gurgacz Ji Paraná RO'

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>10.2 Retirando acentuação</b></p>

# %%
import unidecode 

# Criando variável das palavras não acentuadas
sem_acentos = [unidecode.unidecode(texto) for texto in dados['TRATAMENTO_2']]

# %%
sem_acentos[5]
# Out:
# 'Companhia Aerea LATAM Localizador ZTRPJB Passageiros ACIR MARCOS GURGACZ Matricula 225736 PARLAMENTAR Voo 3117 NVTBSB 01 02 2022'

# %%
# Aplicando o tratamento para os stopwords ficarem sem acentos

stopwords_sem_acento = [unidecode.unidecode(texto) for texto in pontuacao_stopwords]

# %%
# Visualizando 
stopwords_sem_acento
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  'a',
#  'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'as',
#  'ate',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'eramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'esta',
#  'estamos',
#  'estao',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estavamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiveramos',
#  'estiverem',
#  'estivermos',
# ...

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'> Podemos visualizar que foram retirados os acentos, as pontuações e os stopwords sem os acentos. Agora será feito o tratamento da base de dados

# %%
# Criando a coluna do tratamento sem os acentos
dados['TRATAMENTO_3'] = sem_acentos

frase_processada = list()
for despesa in dados['TRATAMENTO_3']:
    nova_frase = list()
    palavras_texto = token_pontuacao.tokenize(despesa)
    for palavra in palavras_texto:
        if palavra not in stopwords_sem_acento:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))
    
dados['TRATAMENTO_3'] = frase_processada

# %%
dados['TRATAMENTO_3'][1]
# Out:
# 'Despesa divulgacao atividade parlamentar website www informanahora'

# %%
dados.head()
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2022    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 2  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 3  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 4  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
#
#              CNPJ_CPF                                         FORNECEDOR  \
# 0      004.948.028-63                      GILBERTO PISELO DO NASCIMENTO
# 1  26.320.603/0001-64                                      INFORMANAHORA
# 2  13.659.201/0001-47                    LINHA PURPURA FOTO E VIDEO LTDA
# 3  23.652.846/0001-01                  ROBERTO GUTIERREZ DA ROCHA M.E.I.
# 4  08.941.827/0001-01  RONDONIA DINÂMICA COM. E SERV. DE INFORMÁTICA ...
#
#            DOCUMENTO        DATA  \
# ...

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>10.3 Medindo os resultados e comparando</b></p>

# %%
# Passando a função de classificação do tratamento 3
# Mostrando na tela
print('Acurracy: ', classificar_texto(dados, 'TRATAMENTO_3', 'TIPO_DESPESA').round(2), '%')
# Out:
# Acurracy:  74.27 %

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'> Com esse tratamento a acurácia melhorou comparada com anteriormente, que era de <b>74,18 % </b>e agora foi obtido <b>74.27%</b> pois agora os dados não possuem a pontuação (.,!<>) e depois foram retirados a acentuação.

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>10.4 Tranformando em minúsculo</b></p>

# %%
frase_processada = list()

for despesa in dados['TRATAMENTO_3']:
    nova_frase = list()
    despesa = despesa.lower()
    palavras_texto = token_pontuacao.tokenize(despesa)
    for palavra in palavras_texto:
        if palavra not in stopwords_sem_acento:
            nova_frase.append(palavra)
    frase_processada.append(' '.join(nova_frase))
 
 # Criando a coluna tratamento 4 com as letras minúsculas
dados['TRATAMENTO_4'] = frase_processada

# %%
dados.head(2)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2022    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2022    1  ACIR GURGACZ                Divulgação da atividade parlamentar
#
#              CNPJ_CPF                     FORNECEDOR          DOCUMENTO  \
# 0      004.948.028-63  GILBERTO PISELO DO NASCIMENTO             001/22
# 1  26.320.603/0001-64                  INFORMANAHORA  000000000000310/A
#
#          DATA                                       DETALHAMENTO  \
# 0  03/01/2022  Despesa com pagamento de aluguel de imóvel par...
# 1  04/01/2022  Despesa com divulgação da atividade parlamenta...
#
#    VALOR_REEMBOLSADO  COD_DOCUMENTO  UF  \
# 0             6000.0        2173614  RO
# 1             1500.0        2173615  RO
#
#                                         TRATAMENTO_1  \
# 0  Despesa pagamento aluguel imóvel uso escritóri...
# 1  Despesa divulgação atividade parlamentar websi...
#
# ...

# %%
dados['DETALHAMENTO'][0]
# Out:
# 'Despesa com pagamento de aluguel de imóvel para uso do escritório político do Senador Acir Gurgacz em Ji Paraná/RO.'

# %%
dados['TRATAMENTO_4'][0]
# Out:
# 'despesa pagamento aluguel imovel uso escritorio politico senador acir gurgacz ji parana ro'

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'> Agora podemos perceber que o texto tratado é mais curto, sem acentos, sem pontuação, com todas as palavras em minúsculo e sem as palavras que não consideramos relevantes.

# %%
# Obtendo a nuvem de palavras com os dados tratados
criando_de_nuvem_palavras(dados,'TRATAMENTO_4')

# %% [markdown]
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'> Em destaque é possível observar a palavra <b>nan</b>, ela representa os dados no qual o detalhamento da despesa não foi inserido, também está em detsque palavras como "parlamentar", essas foram apenas descritas como "despesa parlamentar", a palavra <b>bsb</b> faz referencia ao aeroporto de brasilia, além de outros destaques como <b>combustíveis</b>, matricula

# %%
# Criando gráfico de pareto 

import seaborn as sns
def pareto(texto, coluna_texto, quantidade):

    # Juntando todas as frases totalmente juntas
    todas_palavras = ' '.join([texto for texto in texto[coluna_texto]])

    # Tokenização da frase
    token_frase = token_espaco.tokenize(todas_palavras)

    # Obtendo a frequência das frases, mas queremos é a frequencia das palavras
    frequencia = nltk.FreqDist(token_frase)

    # Criando um dataframe da frequência
    df_frequencia = pd.DataFrame({'Palavra':list(frequencia.keys()),
                                  'Frequencia':list(frequencia.values())})

    # Ordenando as 10 palavras de maior frequência
    df_frequencia_top_quantidade = df_frequencia.nlargest(columns='Frequencia', n=quantidade)

    # Tamanho do gráfico
    plt.figure(figsize=(12,8))

    # Gráfico de barras
    ax = sns.barplot(x = 'Palavra', y = 'Frequencia', data = df_frequencia_top_quantidade, color = 'darkgray')

    # Alterando etiquetas
    ax.set(ylabel = 'Contagem')
    
    # Eixo das acumaladas do gráfico de pareto
    total = df_frequencia_top_quantidade['Frequencia'].sum()
    df_frequencia_top_quantidade['Porcentagem'] = df_frequencia_top_quantidade['Frequencia'].cumsum() / total * 100
    ax2 = ax.twinx()
    sns.lineplot(data=df_frequencia_top_quantidade, x='Palavra', y='Porcentagem', color='blue', sort=False, ax=ax2)

    # Mostrando
    plt.show()

# %%
pareto(dados, 'TRATAMENTO_4', 10)

# %%
stopwords_sem_acento
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~',
#  'a',
#  'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'as',
#  'ate',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'eramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'esta',
#  'estamos',
#  'estao',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estavamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiveramos',
#  'estiverem',
#  'estivermos',
# ...

# %%
from nltk import tokenize

# Token com espaço em branco
token_espaco = tokenize.WhitespaceTokenizer()

#  Tokenizando a frase
token_frase = token_espaco.tokenize(todas_palavras)

# Obtendo a frequência das frases, mas queremos é a frequencia das palavras
frequencia = nltk.FreqDist(token_frase)

# Criando um dataframe da frequência
df_frequencia = pd.DataFrame({'Palavra':list(frequencia.keys()),
                              'Frequencia':list(frequencia.values())})

# Ordenando as 10 palavras de maior frequência
df_frequencia_top_10 = df_frequencia.nlargest(columns='Frequencia', n=10)
df_frequencia_top_10
# Out:
#           Palavra  Frequencia
# 159           nan        4160
# 39     (Matrícula        2112
# 42            Voo        2112
# 3              de        2022
# 30      Companhia        1806
# 31          Aérea        1806
# 33    Localizador        1806
# 35    Passageiros        1806
# 41   PARLAMENTAR)        1494
# 0         Despesa        1092

# %% [markdown]
# <p style='font-size: 22px; line-height: 2; margin: 10px 50px; text-align: justify; color:purple;'><b>10.5 Ngrams</b></p>
#
# <a href = "https://www.nltk.org/_modules/nltk/model/ngram.html" style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify; color:black;'> Documentação Ngrams</a>
#
# <p style='font-size: 16px; line-height: 2; margin: 10px 50px; text-align: justify;'>O método que estávamos utilizando até agora (bag of words), tanto com contagem de frequência quanto aplicando o TF-IDF, não gera um valor que preserve a sequência de palavras. Agora quero passar para vocês o conceito de Ngrams, que é uma forma de manter uma certa sequência no nosso texto.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import ngrams

# Definindo um vetor que tenha uma unica palavra e palavras em bigramas
tfidf = TfidfVectorizer(lowercase=False, ngram_range=(1,2))

# Criando o vetor, sem limitar o max_features
vetor_tfidf = tfidf.fit_transform(dados['TRATAMENTO_4'])

# Variáveis independentes
X = vetor_tfidf  

# Variável dependente
y= dados['TIPO_DESPESA']

# Sendo a classificação a variável dependente
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 12)

# Pegar a regressão logistica e treiná-la
regressao_logistica.fit(X_train, y_train)

# Calculando a acurrácia
acuracia_tfidf_ngrams = regressao_logistica.score(X_test, y_test)

# Obtendo a acurácia dos ngrams
print('Acurracy: ', acuracia_tfidf_ngrams.round(3) * 100, '%')
# Out:
# Acurracy:  73.6 %

# %%
# Vendo as palavras de maior peso
pesos = pd.DataFrame(
    regressao_logistica.coef_[0].T,
    index = tfidf.get_feature_names()
)

# Mostrando os 10 maiores pesos
pesos.nlargest(50,0)
# Out:
#                                0
# escritorio              5.291263
# internet                3.864115
# imovel                  3.604363
# iptu                    2.957488
# energia                 2.575093
# telefone                2.565738
# estado                  2.483908
# escritorio apoio        2.444248
# eletrica                2.431284
# energia eletrica        2.431284
# aluguel                 2.417325
# condominio              2.416842
# apoio                   2.142696
# celular                 1.983444
# escritorio parlamentar  1.966283
# agua                    1.921529
# sala                    1.854802
# locacao imovel          1.849355
# telefonia               1.783482
# politico                1.743953
# despesa aluguel         1.685333
# parlamentar estado      1.594073
# escritorio politico     1.544199
# aluguel escritorio      1.509166
# taxa                    1.478202
# aluguel imovel          1.463117
# pagamento               1.451665
# ...

# %%
# Mostrando os 10 menores pesos
pesos.nsmallest(50,0)
# Out:
#                               0
# combustivel           -2.437584
# matricula             -1.917949
# voo                   -1.825700
# despesa combustivel   -1.706001
# aerea                 -1.676264
# companhia             -1.676264
# companhia aerea       -1.676264
# localizador           -1.676264
# passageiros           -1.676264
# parlamentar           -1.662262
# hospedagem            -1.487048
# veiculo               -1.465510
# parlamentar voo       -1.439519
# material              -1.406652
# locacao               -1.335058
# bsb                   -1.281773
# atividade parlamentar -1.248759
# alimentacao           -1.192097
# referente locacao     -1.155230
# despesa alimentacao   -1.150264
# combustivel serve     -1.078894
# atividade             -1.026945
# divulgacao            -1.024254
# aerea latam           -1.004029
# latam                 -1.004029
# latam localizador     -1.004029
# transporte            -0.994244
# aquisicao             -0.994124
# ...
